# %% [markdown]
# ### This part of the notebook is to achieve the following:
# - Build a machine learning model from the combined data
# - Make predicitons based on user defined input
# - translate predictions into "Football" languages and return to user

# %% [markdown]
# ### Import Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import bz2
import _pickle as cPickle
import dill

from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, RandomizedSearchCV, learning_curve
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, RocCurveDisplay

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier


from sklearn.model_selection import RandomizedSearchCV
from bayes_opt import BayesianOptimization
from sklearn.pipeline import Pipeline
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score, RocCurveDisplay



from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.base import BaseEstimator, RegressorMixin, TransformerMixin
from sklearn.pipeline import Pipeline
from bayes_opt import BayesianOptimization
from sklearn.model_selection import cross_validate

# %% [markdown]
# ### load preprocessed the data from compressed pickle

# %%
#with bz2.BZ2File("NFL_web_app/model_data/20220428_final_combined_NFL_data.pbz2", "rb") as f:

    final_combined_data = cPickle.load(f)
    
    
print(f"The preprocessed data shape is {final_combined_data.shape}, header is \n")

final_combined_data.head().T
# Out:
# The preprocessed data shape is (114827, 1434), header is
#                                                                              0  \
# Offense_0                                                                 82.0
# Offense_1                                                                 80.0
# Offense_2                                                                 87.0
# Offense_3                                                                 76.0
# Offense_4                                                                 81.0
# Offense_5                                                                 80.0
# Offense_6                                                                 86.0
# Offense_7                                                                 69.0
# Offense_8                                                                 29.0
# Offense_9                                                                 22.0
# Offense_10                                                                12.0
# Offense_11                                                                75.0
# Offense_12                                                                54.0
# Offense_13                                                                45.0
# Offense_14                                                                70.0
# Offense_15                                                                87.0
# Offense_16                                                                10.0
# Offense_17                                                                84.0
# Offense_18                                                                88.0
# Offense_19                                                                95.0
# Offense_20                                                                81.0
# Offense_21                                                                67.0
# Offense_22                                                                84.0
# Offense_23                                                                77.0
# Offense_24                                                                77.0
# Offense_25                                                                81.0
# Offense_26                                                                58.0
# Offense_27                                                                74.0
# Offense_28                                                                66.0
# Offense_29                                                                53.0
# Offense_30                                                                51.0
# Offense_31                                                                43.0
# Offense_32                                                                12.0
# Offense_33                                                                10.0
# Offense_34                                                                10.0
# Offense_35                                                                10.0
# Offense_36                                                                55.0
# Offense_37                                                                45.0
# Offense_38                                                                16.0
# Offense_39                                                                15.0
# Offense_40                                                                17.0
# Offense_41                                                                78.0
# Offense_42                                                                81.0
# Offense_43                                                                72.0
# Offense_44                                                                69.0
# Offense_45                                                                67.0
# Offense_46                                                                12.0
# Offense_47                                                                10.0
# Offense_48                                                                77.0
# Offense_49                                                                15.0
# Offense_50                                                                10.0
# Offense_51                                                                 6.0
# Offense_52                                                                 6.0
# Offense_53                                                                10.0
# Offense_54                                                                77.0
# Offense_55                                                               260.0
# Offense_56                                                                30.0
# Offense_57                                                                 8.0
# Offense_58                                                                 0.0
# Offense_59                                                                 1.0
# Offense_60                                                                89.0
# Offense_61                                                                83.0
# Offense_62                                                                88.0
# Offense_63                                                                78.0
# Offense_64                                                                85.0
# Offense_65                                                                96.0
# Offense_66                                                                95.0
# Offense_67                                                                72.0
# Offense_68                                                                26.0
# Offense_69                                                                18.0
# Offense_70                                                                19.0
# Offense_71                                                                65.0
# Offense_72                                                                40.0
# Offense_73                                                                30.0
# Offense_74                                                                70.0
# Offense_75                                                                96.0
# Offense_76                                                                25.0
# Offense_77                                                                94.0
# Offense_78                                                                98.0
# Offense_79                                                                97.0
# Offense_80                                                                69.0
# Offense_81                                                                65.0
# Offense_82                                                                92.0
# Offense_83                                                                78.0
# Offense_84                                                                79.0
# Offense_85                                                                82.0
# Offense_86                                                                68.0
# Offense_87                                                                41.0
# Offense_88                                                                38.0
# Offense_89                                                                35.0
# Offense_90                                                                38.0
# Offense_91                                                                48.0
# Offense_92                                                                22.0
# Offense_93                                                                22.0
# Offense_94                                                                10.0
# Offense_95                                                                10.0
# Offense_96                                                                40.0
# Offense_97                                                                42.0
# Offense_98                                                                30.0
# Offense_99                                                                18.0
# Offense_100                                                               14.0
# Offense_101                                                               95.0
# Offense_102                                                               95.0
# Offense_103                                                               90.0
# Offense_104                                                               88.0
# Offense_105                                                               81.0
# Offense_106                                                               12.0
# Offense_107                                                               10.0
# Offense_108                                                               86.0
# Offense_109                                                               15.0
# Offense_110                                                               10.0
# Offense_111                                                                6.0
# Offense_112                                                                6.0
# Offense_113                                                               10.0
# Offense_114                                                               75.0
# Offense_115                                                              218.0
# Offense_116                                                               35.0
# Offense_117                                                               14.0
# Offense_118                                                                0.0
# Offense_119                                                                1.0
# Offense_120                                                               77.0
# Offense_121                                                               96.0
# Offense_122                                                               94.0
# Offense_123                                                               40.0
# Offense_124                                                               92.0
# Offense_125                                                               74.0
# Offense_126                                                               84.0
# Offense_127                                                               68.0
# Offense_128                                                               28.0
# Offense_129                                                               21.0
# Offense_130                                                               20.0
# Offense_131                                                               44.0
# Offense_132                                                               27.0
# Offense_133                                                               24.0
# Offense_134                                                               79.0
# Offense_135                                                               88.0
# Offense_136                                                               77.0
# Offense_137                                                               81.0
# Offense_138                                                               88.0
# Offense_139                                                               65.0
# Offense_140                                                               29.0
# Offense_141                                                               80.0
# Offense_142                                                               86.0
# Offense_143                                                               36.0
# Offense_144                                                               80.0
# Offense_145                                                               90.0
# Offense_146                                                               45.0
# Offense_147                                                               26.0
# Offense_148                                                               18.0
# Offense_149                                                               13.0
# Offense_150                                                               13.0
# Offense_151                                                               25.0
# Offense_152                                                               22.0
# Offense_153                                                               23.0
# Offense_154                                                               10.0
# Offense_155                                                               10.0
# Offense_156                                                               30.0
# Offense_157                                                               24.0
# Offense_158                                                               27.0
# Offense_159                                                               19.0
# Offense_160                                                               25.0
# Offense_161                                                               79.0
# Offense_162                                                               79.0
# Offense_163                                                               77.0
# Offense_164                                                               78.0
# Offense_165                                                               82.0
# Offense_166                                                               15.0
# Offense_167                                                               15.0
# Offense_168                                                               63.0
# Offense_169                                                               29.0
# Offense_170                                                               25.0
# Offense_171                                                               21.0
# Offense_172                                                               15.0
# Offense_173                                                               15.0
# Offense_174                                                               70.0
# Offense_175                                                              160.0
# Offense_176                                                               26.0
# Offense_177                                                                3.0
# Offense_178                                                                0.0
# Offense_179                                                                1.0
# Offense_180                                                               76.0
# Offense_181                                                               68.0
# Offense_182                                                               77.0
# Offense_183                                                               88.0
# Offense_184                                                               73.0
# Offense_185                                                               72.0
# Offense_186                                                               35.0
# Offense_187                                                               40.0
# Offense_188                                                               10.0
# Offense_189                                                               13.0
# Offense_190                                                                6.0
# Offense_191                                                               86.0
# Offense_192                                                               73.0
# Offense_193                                                               45.0
# Offense_194                                                                5.0
# Offense_195                                                               80.0
# Offense_196                                                               10.0
# Offense_197                                                               82.0
# Offense_198                                                               92.0
# Offense_199                                                               87.0
# Offense_200                                                               21.0
# Offense_201                                                               10.0
# Offense_202                                                               15.0
# Offense_203                                                               10.0
# Offense_204                                                               10.0
# Offense_205                                                               10.0
# Offense_206                                                               85.0
# Offense_207                                                               85.0
# Offense_208                                                               85.0
# Offense_209                                                               71.0
# Offense_210                                                               74.0
# Offense_211                                                               86.0
# Offense_212                                                               12.0
# Offense_213                                                               12.0
# Offense_214                                                               10.0
# Offense_215                                                               10.0
# Offense_216                                                               35.0
# Offense_217                                                               32.0
# Offense_218                                                               25.0
# Offense_219                                                               18.0
# Offense_220                                                               12.0
# Offense_221                                                               12.0
# Offense_222                                                               10.0
# Offense_223                                                               10.0
# Offense_224                                                                5.0
# Offense_225                                                                5.0
# Offense_226                                                               25.0
# Offense_227                                                               10.0
# Offense_228                                                               12.0
# Offense_229                                                                6.0
# Offense_230                                                                6.0
# Offense_231                                                                6.0
# Offense_232                                                                6.0
# Offense_233                                                                6.0
# Offense_234                                                               77.0
# Offense_235                                                              307.0
# Offense_236                                                               24.0
# Offense_237                                                                3.0
# Offense_238                                                                0.0
# Offense_239                                                                1.0
# Offense_240                                                               73.0
# Offense_241                                                               59.0
# Offense_242                                                               77.0
# Offense_243                                                               95.0
# Offense_244                                                               55.0
# Offense_245                                                               67.0
# Offense_246                                                               23.0
# Offense_247                                                               40.0
# Offense_248                                                               16.0
# Offense_249                                                               14.0
# Offense_250                                                               29.0
# Offense_251                                                               79.0
# Offense_252                                                               73.0
# Offense_253                                                               14.0
# Offense_254                                                                8.0
# Offense_255                                                               25.0
# Offense_256                                                               10.0
# Offense_257                                                               86.0
# Offense_258                                                               80.0
# Offense_259                                                               90.0
# Offense_260                                                               10.0
# Offense_261                                                               18.0
# Offense_262                                                               10.0
# Offense_263                                                               10.0
# Offense_264                                                               10.0
# Offense_265                                                               10.0
# Offense_266                                                               80.0
# Offense_267                                                               79.0
# Offense_268                                                               75.0
# Offense_269                                                               74.0
# Offense_270                                                               71.0
# Offense_271                                                               78.0
# Offense_272                                                               12.0
# Offense_273                                                                7.0
# Offense_274                                                               10.0
# Offense_275                                                               10.0
# Offense_276                                                               14.0
# Offense_277                                                               23.0
# Offense_278                                                               24.0
# Offense_279                                                               16.0
# Offense_280                                                               12.0
# Offense_281                                                               15.0
# Offense_282                                                               15.0
# Offense_283                                                               15.0
# Offense_284                                                                5.0
# Offense_285                                                                5.0
# Offense_286                                                               20.0
# Offense_287                                                               10.0
# Offense_288                                                               15.0
# Offense_289                                                                6.0
# Offense_290                                                                6.0
# Offense_291                                                                6.0
# Offense_292                                                                6.0
# Offense_293                                                                6.0
# Offense_294                                                               76.0
# Offense_295                                                              330.0
# Offense_296                                                               31.0
# Offense_297                                                                9.0
# Offense_298                                                                0.0
# Offense_299                                                                1.0
# Offense_300                                                               76.0
# Offense_301                                                               61.0
# Offense_302                                                               75.0
# Offense_303                                                               92.0
# Offense_304                                                               65.0
# Offense_305                                                               74.0
# Offense_306                                                               32.0
# Offense_307                                                               40.0
# Offense_308                                                               14.0
# Offense_309                                                               35.0
# Offense_310                                                               22.0
# Offense_311                                                               82.0
# Offense_312                                                               72.0
# Offense_313                                                               31.0
# Offense_314                                                                8.0
# Offense_315                                                               60.0
# Offense_316                                                               10.0
# Offense_317                                                               88.0
# Offense_318                                                               80.0
# Offense_319                                                               97.0
# Offense_320                                                               25.0
# Offense_321                                                               18.0
# Offense_322                                                               22.0
# Offense_323                                                               35.0
# Offense_324                                                               20.0
# Offense_325                                                               10.0
# Offense_326                                                               86.0
# Offense_327                                                               82.0
# Offense_328                                                               82.0
# Offense_329                                                               72.0
# Offense_330                                                               71.0
# Offense_331                                                               85.0
# Offense_332                                                               12.0
# Offense_333                                                               15.0
# Offense_334                                                               35.0
# Offense_335                                                               10.0
# Offense_336                                                               40.0
# Offense_337                                                               42.0
# Offense_338                                                               17.0
# Offense_339                                                               12.0
# Offense_340                                                               12.0
# Offense_341                                                               15.0
# Offense_342                                                               15.0
# Offense_343                                                               20.0
# Offense_344                                                               10.0
# Offense_345                                                                6.0
# Offense_346                                                               33.0
# Offense_347                                                               10.0
# Offense_348                                                               15.0
# Offense_349                                                                6.0
# Offense_350                                                                6.0
# Offense_351                                                                6.0
# Offense_352                                                                6.0
# Offense_353                                                                6.0
# Offense_354                                                               77.0
# Offense_355                                                              331.0
# Offense_356                                                               31.0
# Offense_357                                                                8.0
# Offense_358                                                                0.0
# Offense_359                                                                1.0
# Offense_360                                                               80.0
# Offense_361                                                               67.0
# Offense_362                                                               85.0
# Offense_363                                                               88.0
# Offense_364                                                               73.0
# Offense_365                                                               87.0
# Offense_366                                                               54.0
# Offense_367                                                               60.0
# Offense_368                                                               16.0
# Offense_369                                                               21.0
# Offense_370                                                               23.0
# Offense_371                                                               78.0
# Offense_372                                                               78.0
# Offense_373                                                               35.0
# Offense_374                                                                8.0
# Offense_375                                                               75.0
# Offense_376                                                               11.0
# Offense_377                                                               90.0
# Offense_378                                                               92.0
# Offense_379                                                               74.0
# Offense_380                                                               35.0
# Offense_381                                                               15.0
# Offense_382                                                               15.0
# Offense_383                                                               10.0
# Offense_384                                                               10.0
# Offense_385                                                               10.0
# Offense_386                                                               87.0
# Offense_387                                                               78.0
# Offense_388                                                               74.0
# Offense_389                                                               79.0
# Offense_390                                                               74.0
# Offense_391                                                               88.0
# Offense_392                                                               12.0
# Offense_393                                                               15.0
# Offense_394                                                               10.0
# Offense_395                                                               10.0
# Offense_396                                                               25.0
# Offense_397                                                               28.0
# Offense_398                                                               10.0
# Offense_399                                                               15.0
# Offense_400                                                               20.0
# Offense_401                                                               15.0
# Offense_402                                                               15.0
# Offense_403                                                               15.0
# Offense_404                                                                5.0
# Offense_405                                                                5.0
# Offense_406                                                               23.0
# Offense_407                                                               10.0
# Offense_408                                                               20.0
# Offense_409                                                                6.0
# Offense_410                                                                6.0
# Offense_411                                                                6.0
# Offense_412                                                                6.0
# Offense_413                                                                6.0
# Offense_414                                                               76.0
# Offense_415                                                              311.0
# Offense_416                                                               28.0
# Offense_417                                                                5.0
# Offense_418                                                                0.0
# Offense_419                                                                1.0
# Offense_420                                                               74.0
# Offense_421                                                               62.0
# Offense_422                                                               80.0
# Offense_423                                                               87.0
# Offense_424                                                               58.0
# Offense_425                                                               86.0
# Offense_426                                                               25.0
# Offense_427                                                               40.0
# Offense_428                                                               17.0
# Offense_429                                                               19.0
# Offense_430                                                               16.0
# Offense_431                                                               72.0
# Offense_432                                                               76.0
# Offense_433                                                               26.0
# Offense_434                                                                8.0
# Offense_435                                                               29.0
# Offense_436                                                               10.0
# Offense_437                                                               87.0
# Offense_438                                                               80.0
# Offense_439                                                               92.0
# Offense_440                                                               10.0
# Offense_441                                                               15.0
# Offense_442                                                               10.0
# Offense_443                                                               10.0
# Offense_444                                                               10.0
# Offense_445                                                               10.0
# Offense_446                                                               85.0
# Offense_447                                                               72.0
# Offense_448                                                               71.0
# Offense_449                                                               77.0
# Offense_450                                                               74.0
# Offense_451                                                               83.0
# Offense_452                                                               12.0
# Offense_453                                                               15.0
# Offense_454                                                               10.0
# Offense_455                                                               10.0
# Offense_456                                                               26.0
# Offense_457                                                               33.0
# Offense_458                                                               22.0
# Offense_459                                                               22.0
# Offense_460                                                               21.0
# Offense_461                                                               16.0
# Offense_462                                                               14.0
# Offense_463                                                               17.0
# Offense_464                                                                7.0
# Offense_465                                                                5.0
# Offense_466                                                               20.0
# Offense_467                                                               10.0
# Offense_468                                                               15.0
# Offense_469                                                                6.0
# Offense_470                                                                6.0
# Offense_471                                                                6.0
# Offense_472                                                                6.0
# Offense_473                                                                6.0
# Offense_474                                                               73.0
# Offense_475                                                              307.0
# Offense_476                                                               32.0
# Offense_477                                                                8.0
# Offense_478                                                                0.0
# Offense_479                                                                1.0
# Offense_480                                                               79.0
# Offense_481                                                               65.0
# Offense_482                                                               66.0
# Offense_483                                                               51.0
# Offense_484                                                               67.0
# Offense_485                                                               81.0
# Offense_486                                                               32.0
# Offense_487                                                               57.0
# Offense_488                                                               90.0
# Offense_489                                                               15.0
# Offense_490                                                               12.0
# Offense_491                                                               13.0
# Offense_492                                                               12.0
# Offense_493                                                               28.0
# Offense_494                                                               36.0
# Offense_495                                                               62.0
# Offense_496                                                               10.0
# Offense_497                                                               78.0
# Offense_498                                                               95.0
# Offense_499                                                               84.0
# Offense_500                                                               24.0
# Offense_501                                                               37.0
# Offense_502                                                               59.0
# Offense_503                                                               28.0
# Offense_504                                                               50.0
# Offense_505                                                               55.0
# Offense_506                                                               13.0
# Offense_507                                                               13.0
# Offense_508                                                               13.0
# Offense_509                                                               12.0
# Offense_510                                                               12.0
# Offense_511                                                               10.0
# Offense_512                                                               37.0
# Offense_513                                                               92.0
# Offense_514                                                               10.0
# Offense_515                                                               10.0
# Offense_516                                                               22.0
# Offense_517                                                               14.0
# Offense_518                                                               26.0
# Offense_519                                                               13.0
# Offense_520                                                               31.0
# Offense_521                                                               12.0
# Offense_522                                                               10.0
# Offense_523                                                               10.0
# Offense_524                                                               10.0
# Offense_525                                                               10.0
# Offense_526                                                               12.0
# Offense_527                                                               10.0
# Offense_528                                                               12.0
# Offense_529                                                               88.0
# Offense_530                                                               81.0
# Offense_531                                                               80.0
# Offense_532                                                               86.0
# Offense_533                                                               80.0
# Offense_534                                                               76.0
# Offense_535                                                              224.0
# Offense_536                                                               30.0
# Offense_537                                                                8.0
# Offense_538                                                                0.0
# Offense_539                                                                1.0
# Offense_540                                                               93.0
# Offense_541                                                               92.0
# Offense_542                                                               91.0
# Offense_543                                                               83.0
# Offense_544                                                               93.0
# Offense_545                                                               95.0
# Offense_546                                                               78.0
# Offense_547                                                               85.0
# Offense_548                                                               25.0
# Offense_549                                                               20.0
# Offense_550                                                               17.0
# Offense_551                                                               40.0
# Offense_552                                                               46.0
# Offense_553                                                               25.0
# Offense_554                                                               96.0
# Offense_555                                                               91.0
# Offense_556                                                               83.0
# Offense_557                                                               90.0
# Offense_558                                                               95.0
# Offense_559                                                               90.0
# Offense_560                                                               89.0
# Offense_561                                                               93.0
# Offense_562                                                               95.0
# Offense_563                                                               91.0
# Offense_564                                                               83.0
# Offense_565                                                               94.0
# Offense_566                                                               40.0
# Offense_567                                                               32.0
# Offense_568                                                               34.0
# Offense_569                                                               30.0
# Offense_570                                                               24.0
# Offense_571                                                               42.0
# Offense_572                                                               26.0
# Offense_573                                                               20.0
# Offense_574                                                               15.0
# Offense_575                                                               15.0
# Offense_576                                                               12.0
# Offense_577                                                               35.0
# Offense_578                                                               15.0
# Offense_579                                                               10.0
# Offense_580                                                               15.0
# Offense_581                                                               72.0
# Offense_582                                                               74.0
# ...
# Defense_577                                                               82.0
# Defense_578                                                               87.0
# Defense_579                                                               80.0
# Defense_580                                                               81.0
# Defense_581                                                               50.0
# Defense_582                                                               60.0
# Defense_583                                                               20.0
# Defense_584                                                               10.0
# Defense_585                                                               10.0
# Defense_586                                                               59.0
# Defense_587                                                               66.0
# Defense_588                                                               20.0
# Defense_589                                                                6.0
# Defense_590                                                                6.0
# Defense_591                                                                6.0
# Defense_592                                                                6.0
# Defense_593                                                                6.0
# Defense_594                                                               69.0
# Defense_595                                                              186.0
# Defense_596                                                               26.0
# Defense_597                                                                4.0
# Defense_598                                                                0.0
# Defense_599                                                                1.0
# Defense_600                                                               89.0
# Defense_601                                                               87.0
# Defense_602                                                               88.0
# Defense_603                                                               76.0
# Defense_604                                                               88.0
# Defense_605                                                               85.0
# Defense_606                                                               70.0
# Defense_607                                                               65.0
# Defense_608                                                               34.0
# Defense_609                                                               21.0
# Defense_610                                                               18.0
# Defense_611                                                               20.0
# Defense_612                                                               25.0
# Defense_613                                                               77.0
# Defense_614                                                               46.0
# Defense_615                                                               89.0
# Defense_616                                                               76.0
# Defense_617                                                               90.0
# Defense_618                                                               91.0
# Defense_619                                                               93.0
# Defense_620                                                               48.0
# Defense_621                                                               61.0
# Defense_622                                                               59.0
# Defense_623                                                               56.0
# Defense_624                                                               63.0
# Defense_625                                                               66.0
# Defense_626                                                               70.0
# Defense_627                                                               33.0
# Defense_628                                                               33.0
# Defense_629                                                               34.0
# Defense_630                                                               33.0
# Defense_631                                                               25.0
# Defense_632                                                               16.0
# Defense_633                                                               15.0
# Defense_634                                                               47.0
# Defense_635                                                               55.0
# Defense_636                                                               64.0
# Defense_637                                                               92.0
# Defense_638                                                               85.0
# Defense_639                                                               79.0
# Defense_640                                                               85.0
# Defense_641                                                               45.0
# Defense_642                                                               43.0
# Defense_643                                                               44.0
# Defense_644                                                               34.0
# Defense_645                                                               29.0
# Defense_646                                                               94.0
# Defense_647                                                               81.0
# Defense_648                                                               42.0
# Defense_649                                                               15.0
# Defense_650                                                               15.0
# Defense_651                                                               15.0
# Defense_652                                                                6.0
# Defense_653                                                                6.0
# Defense_654                                                               72.0
# Defense_655                                                              211.0
# Defense_656                                                               23.0
# Defense_657                                                                2.0
# Defense_658                                                                0.0
# Defense_659                                                                1.0
# GameId                                                              2018121600
# GameDate                                                            2018-12-16
# Quarter                                                                      4
# Minute                                                                       0
# Second                                                                      41
# OffenseTeam                                                                ARI
# DefenseTeam                                                                ATL
# Down                                                                         1
# ToGo                                                                        10
# YardLine                                                                    49
# SeriesFirstDown                                                              1
# Description                  (:41) (NO HUDDLE, SHOTGUN) 7-M.GLENNON PASS SH...
# SeasonYear                                                                2018
# Yards                                                                       16
# Formation                                                    NO HUDDLE SHOTGUN
# IsRush                                                                       0
# IsPass                                                                       1
# OffenseTeam_ARI                                                            1.0
# OffenseTeam_ATL                                                            0.0
# OffenseTeam_BAL                                                            0.0
# OffenseTeam_BUF                                                            0.0
# OffenseTeam_CAR                                                            0.0
# OffenseTeam_CHI                                                            0.0
# OffenseTeam_CIN                                                            0.0
# OffenseTeam_CLE                                                            0.0
# OffenseTeam_DAL                                                            0.0
# OffenseTeam_DEN                                                            0.0
# OffenseTeam_DET                                                            0.0
# OffenseTeam_GB                                                             0.0
# OffenseTeam_HOU                                                            0.0
# OffenseTeam_IND                                                            0.0
# OffenseTeam_JAX                                                            0.0
# OffenseTeam_KC                                                             0.0
# OffenseTeam_LA                                                             0.0
# OffenseTeam_LAC                                                            0.0
# OffenseTeam_LV                                                             0.0
# OffenseTeam_MIA                                                            0.0
# OffenseTeam_MIN                                                            0.0
# OffenseTeam_NE                                                             0.0
# OffenseTeam_NO                                                             0.0
# OffenseTeam_NYG                                                            0.0
# OffenseTeam_NYJ                                                            0.0
# OffenseTeam_PHI                                                            0.0
# OffenseTeam_PIT                                                            0.0
# OffenseTeam_SEA                                                            0.0
# OffenseTeam_SF                                                             0.0
# OffenseTeam_TB                                                             0.0
# OffenseTeam_TEN                                                            0.0
# OffenseTeam_WAS                                                            0.0
# DefenseTeam_ARI                                                            0.0
# DefenseTeam_ATL                                                            1.0
# DefenseTeam_BAL                                                            0.0
# DefenseTeam_BUF                                                            0.0
# DefenseTeam_CAR                                                            0.0
# DefenseTeam_CHI                                                            0.0
# DefenseTeam_CIN                                                            0.0
# DefenseTeam_CLE                                                            0.0
# DefenseTeam_DAL                                                            0.0
# DefenseTeam_DEN                                                            0.0
# DefenseTeam_DET                                                            0.0
# DefenseTeam_GB                                                             0.0
# DefenseTeam_HOU                                                            0.0
# DefenseTeam_IND                                                            0.0
# DefenseTeam_JAX                                                            0.0
# DefenseTeam_KC                                                             0.0
# DefenseTeam_LA                                                             0.0
# DefenseTeam_LAC                                                            0.0
# DefenseTeam_LV                                                             0.0
# DefenseTeam_MIA                                                            0.0
# DefenseTeam_MIN                                                            0.0
# DefenseTeam_NE                                                             0.0
# DefenseTeam_NO                                                             0.0
# DefenseTeam_NYG                                                            0.0
# DefenseTeam_NYJ                                                            0.0
# DefenseTeam_PHI                                                            0.0
# DefenseTeam_PIT                                                            0.0
# DefenseTeam_SEA                                                            0.0
# DefenseTeam_SF                                                             0.0
# DefenseTeam_TB                                                             0.0
# DefenseTeam_TEN                                                            0.0
# DefenseTeam_WAS                                                            0.0
# Formation_NO HUDDLE                                                        0.0
# Formation_NO HUDDLE SHOTGUN                                                1.0
# Formation_PUNT                                                             0.0
# Formation_SHOTGUN                                                          0.0
# Formation_UNDER CENTER                                                     0.0
# Formation_WILDCAT                                                          0.0
# PlayType_PASS                                                              1.0
# PlayType_RUSH                                                              0.0
# PassType_(SHOTGUN) 10-THILL                                                0.0
# PassType_BACK TO                                                           0.0
# PassType_DEEP LEFT                                                         0.0
# PassType_DEEP MIDDLE                                                       0.0
# PassType_DEEP RIGHT                                                        0.0
# PassType_INTENDED FOR                                                      0.0
# PassType_INTERCEPTED BY                                                    0.0
# PassType_LEFT TO                                                           0.0
# PassType_MIDDLE TO                                                         0.0
# PassType_MIDDLE [55-FCLARK]                                                0.0
# PassType_NOT LISTED                                                        0.0
# PassType_RIGHT TO                                                          0.0
# PassType_SHORT LEFT                                                        1.0
# PassType_SHORT MIDDLE                                                      0.0
# PassType_SHORT RIGHT                                                       0.0
# PassType_[58-H.LANDRY III]                                                 0.0
# RushDirection_CENTER                                                       0.0
# RushDirection_LEFT END                                                     0.0
# RushDirection_LEFT GUARD                                                   0.0
# RushDirection_LEFT TACKLE                                                  0.0
# RushDirection_RIGHT END                                                    0.0
# RushDirection_RIGHT GUARD                                                  0.0
# RushDirection_RIGHT TACKLE                                                 0.0
# Time_in_seconds                                                           3559
# Yards_vs_ToGo                                                              1.6

# %% [markdown]
# ### Generate train and test data with an 80/20 split

# %%
#split train and test data

#X = final_res.drop(columns=["SeriesFirstDown", "GameId", 'level_1', "GameDate"])
#y = final_res.SeriesFirstDown.tolist()

X = final_combined_data.drop(columns=["Yards_vs_ToGo"], axis=1)

y = final_combined_data.Yards_vs_ToGo.tolist()

split_ratio = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=split_ratio, random_state=42)


print(f"X_train shape is {X_train.shape}")
print(f"X_test shape is {X_test.shape}")

print(f"y_train shape is {pd.DataFrame(y_train).shape}")
print(f"y_test shape is {pd.DataFrame(y_test).shape}")
# Out:
# X_train shape is (91861, 1433)
# X_test shape is (22966, 1433)
# y_train shape is (91861, 1)
# y_test shape is (22966, 1)

# %% [markdown]
# ### Remove unwanted columns in both train and test data
# - Drop columns: "SeriesFirstDown", "GameId", "GameDate", "ToGo", "Yards", "Description", "SeasonYear",
# - Formation, OffenseTeam, DefenseTeam, Quarter, Minute, Second

# %%
X_train_final = X_train.drop(columns=["SeriesFirstDown", "GameId", "GameDate", 
                                     "ToGo", "Yards", "Description", "SeasonYear",
                                      "Formation", "OffenseTeam", "DefenseTeam", "Quarter", "Minute", "Second"
                                     ], axis=1)

X_test_final = X_test.drop(columns=["SeriesFirstDown", "GameId", "GameDate", 
                                     "ToGo", "Yards", "Description", "SeasonYear",
                                      "Formation", "OffenseTeam", "DefenseTeam", "Quarter", "Minute", "Second"
                                     ], axis=1)

print(f"X_train shape is {X_train_final.shape}")
print(f"X_test shape is {X_test_final.shape}")

print(f"y_train shape is {pd.DataFrame(y_train).shape}")
print(f"y_test shape is {pd.DataFrame(y_test).shape}")
# Out:
# X_train shape is (91861, 1420)
# X_test shape is (22966, 1420)
# y_train shape is (91861, 1)
# y_test shape is (22966, 1)

# %% [markdown]
# ### Fit the data with linear plus nonlinear regression model
# - First fit the data with regularized linear model (Ridge)
# - Then fit the residual with random forest regression model
# - Combine linear and non-linear fits to genearte the final prediction results

# %%
class linear_plus_nonlinear(BaseEstimator, TransformerMixin):
    
    '''
     Define the linear + non-linear ensemble predictor model class
    '''
    def __init__(self, alpha=1, max_depth=1, min_samples_leaf=1, n_estimators=100):
        
        self = self
        self.alpha = alpha
        self.max_depth = max_depth
        self.min_samples_leaf = min_samples_leaf
        self.n_estimators = n_estimators
        
    
    def fit(self, X, y):
        ridge = Ridge(alpha=self.alpha)
        rf = RandomForestRegressor(max_depth=self.max_depth, min_samples_leaf=self.min_samples_leaf, n_estimators=self.n_estimators)
        self.linear_fit = ridge.fit(X, y)
        residual = y - (self.linear_fit.predict(X))
        #print(f"residual shape is {residual.shape}")
        self.nonlinear_fit = rf.fit(X, residual)
        
        return self
    
    def predict(self, X):
        return self.linear_fit.predict(X) + self.nonlinear_fit.predict(X)
    
    
    '''def score(self, X, y):
        predict_y = self.predict(X)
        return 1 - np.dot(np.array(predict_y - y).T, np.array(predict_y -y)) / np.dot(np.array(y-np.mean(y)).T, np.array(y-np.mean(y)))
    '''

# %%
def my_eval(n_estimators, min_samples_leaf, max_depth, alpha):
    
    '''
    Searching for best hyperparameters for the model
    using Bayesian Optimizer
    '''
    model = Pipeline([('scaler', StandardScaler()),
                      ('mix', linear_plus_nonlinear(alpha=alpha, min_samples_leaf=int(min_samples_leaf),
                                                       max_depth=int(max_depth), n_estimators=int(n_estimators)))]) 
    
    cv_score = cross_validate(model, X_train_final, y_train, cv=5, scoring='r2', n_jobs=-1)
    
    return np.mean(cv_score['test_score'])



param_grid = param_grid = {'alpha': (1e-4, 1e4), 'max_depth': (2, 50), 'min_samples_leaf': (2, 100), 'n_estimators': (10, 500)}

myBO = BayesianOptimization(my_eval, param_grid, verbose = 2,
                                 random_state = 42)

myBO.maximize(n_iter=100, init_points=2)
# Out:
# |   iter    |  target   |   alpha   | max_depth | min_sa... | n_esti... |
# -------------------------------------------------------------------------
# |  1        |  0.08442  |  3.745e+0 |  47.63    |  73.74    |  303.3    |
# |  2        |  0.08104  |  1.56e+03 |  9.488    |  7.692    |  434.4    |
# |  3        |  0.07645  |  7.231e+0 |  34.07    |  23.84    |  41.31    |
# |  4        |  0.08396  |  4.631e+0 |  30.18    |  58.53    |  489.3    |
# |  5        |  0.05708  |  9.999e+0 |  2.06     |  30.28    |  490.8    |
# |  6        |  0.08473  |  9.708e+0 |  36.06    |  99.4     |  193.2    |
# |  7        |  0.08317  |  4.63e+03 |  30.58    |  45.73    |  480.1    |
# |  8        |  0.07554  |  9.527e+0 |  46.95    |  50.13    |  12.93    |
# |  9        |  0.08456  |  4.854e+0 |  20.29    |  99.67    |  484.5    |
# |  10       |  0.08458  |  3.988e+0 |  32.39    |  83.81    |  412.4    |

# %% [markdown]
# ### Test the best model (mixed_best)

# %%
mixed_best = linear_plus_nonlinear(alpha=9.708e+0, min_samples_leaf=int(99.4),
                                                       max_depth=int(36.06), n_estimators=int(193.2))
print(mixed_best)
# Out:
# linear_plus_nonlinear(alpha=9.708, max_depth=36, min_samples_leaf=99,
#                       n_estimators=193)

# %%
#mixed_best.fit(X_train_final, y_train)

y_pred = mixed_best.predict(X_test_final)

# %%
r_square = np.dot((np.array(y_pred) - np.mean(y_test)).T, (np.array(y_pred) - np.mean(y_test))) / np.dot((np.array(y_test) - np.mean(y_test)).T, (np.array(y_test) - np.mean(y_test)))

# %%
r_square
# Out:
# 0.08483766429343653

# %%
X_test["Yards_vs_ToGo"] = y_test
X_test["Predicted_Yards_toGO"] = y_pred

# %%
X_test["Predicted_Yards_toGO"].describe()
# Out:
# count    22966.000000
# mean         1.054626
# std          0.673303
# min         -0.147623
# 25%          0.570218
# 50%          0.877649
# 75%          1.383015
# max          7.332787
# Name: Predicted_Yards_toGO, dtype: float64

# %% [markdown]
# ### Local test of the web app prototype
# - Create a self-defined mock user input for season year, offense/defense team, quarter, yards, down, etc.
# - Enumerate all possible pass/rush directions and formations, transform into one hot matrix and combine together with user-defined input features.
# - Make predictions on the combined dataset, using a self-defined sigmoid function to convert the response variable to probabilities.
# - Rank in descending order every combination of pass/rush directions according to calculated sigmoid probabilities, defined as "chance of success", select Top 5, tranlate them into "Football" language and output to the user.

# %%
'''
Self define a mock user input
'''

#input criteria:
year = 2021
offenseTeam = "MIA"
defenseTeam = "NYJ"

Quarter = 4
minutes = 10
seconds = 5

Down = 1

Yardline = 98

togo = 2
# Out:
# array(['ARI', 'ATL', 'BAL', 'BUF', 'CAR', 'CHI', 'CIN', 'CLE', 'DAL',
#        'DEN', 'DET', 'GB', 'HOU', 'IND', 'JAX', 'KC', 'LA', 'LAC', 'LV',
#        'MIA', 'MIN', 'NE', 'NO', 'NYG', 'NYJ', 'PHI', 'PIT', 'SEA', 'SF',
#        'TB', 'TEN', 'WAS'], dtype=object)

# %%
'''
Augment data based on combination of PassType and Rushdirection for each Formation

Note that NOT all teams have games against each other in a season, so the following script may result in bugs:

subset_combined = final_combined_data.loc[np.logical_and(np.logical_and(final_combined_data.OffenseTeam=="MIA", \
                                                         final_combined_data.DefenseTeam=="NYJ"), \
                                                         final_combined_data.SeasonYear==2018)]         

'''



def list_all_PassType_Rushdirection(formation_df, final_Pass_Rush_combined):
    
    '''
    Function to create all combination of PassType and Rushdirection for each Formation
    '''
    
    return_df = pd.concat([formation_df.iloc[0,:]]*final_Pass_Rush_combined.shape[0], axis=1, ignore_index=True).T
    
    return_df.loc[:,final_Pass_Rush_combined.columns.tolist()] = final_Pass_Rush_combined
    
    
    return(return_df)
    
    


#step 1 get all the data for a given offense team in a season
offense_data = final_combined_data.loc[np.logical_and(final_combined_data.OffenseTeam=="MIA", \
                                                         final_combined_data.SeasonYear==2018)].reset_index(drop=True)
#step 2 get all the data for a given offense team in a season
defense_data = final_combined_data.loc[np.logical_and(final_combined_data.DefenseTeam=="LA", \
                                                      final_combined_data.SeasonYear==2018)].reset_index(drop=True)


#step 3 replace all the defence variables in the offensedata with the columns in the DefenseTeam


offense_data.loc[:, [cname for cname in offense_data.columns if "Defense" in cname]] = \
pd.concat([defense_data.loc[0, [cname for cname in defense_data.columns if "Defense" in cname]]]\
          *offense_data.shape[0], axis=1, ignore_index=True).T


subset_combined = offense_data
                                                      
#step 4 remove offense and defense data                                                 

del(offense_data)

del(defense_data)




#step 5 get list of all unique formation from the data, then augment each formation with 
#all possible combinations of PassType and RushDirections

subset_combined = subset_combined.reset_index(drop=True)


list_of_unique_formations = subset_combined.Formation.tolist()



list_of_unique_PassType = [x.split("_")[1] for x in subset_combined.columns if "PassType" in x]

list_of_unique_RushDirection = [x.split("_")[1] for x in subset_combined.columns if "RushDirection" in x]



PassType_dummies = pd.get_dummies(list_of_unique_PassType, prefix='PassType')

RushDirection_dummies = pd.get_dummies(list_of_unique_RushDirection , prefix='RushDirection')

empty_RushDirection = pd.DataFrame(np.zeros(shape=(PassType_dummies.shape[0], len(list_of_unique_RushDirection))),
                                  columns=RushDirection_dummies.columns)
empty_PassType = pd.DataFrame(np.zeros(shape=(RushDirection_dummies.shape[0], len(list_of_unique_PassType))),
                                  columns=PassType_dummies.columns)



final_PassType_df = pd.concat([PassType_dummies, empty_RushDirection], axis=1)

final_PassType_df['PlayType_PASS'] = 1
final_PassType_df['PlayType_RUSH'] = 0


final_RushDirection_df = pd.concat([empty_PassType, RushDirection_dummies], axis=1)

final_RushDirection_df ['PlayType_PASS'] = 0
final_RushDirection_df ['PlayType_RUSH'] = 1


final_Pass_Rush_combined = pd.concat([final_PassType_df, final_RushDirection_df], axis=0, ignore_index=True)



#Step 6. Combined both datasets to form the final "test data"

subset_combined = subset_combined.groupby(['Formation']).\
apply(lambda x: list_all_PassType_Rushdirection(x, final_Pass_Rush_combined))

print(subset_combined.shape)
# Out:
# (92, 1434)

# %% [markdown]
# ### Final processing of the test data
# - Assign user defined values to corresponding columns
# - Drop unwanted columns
# - self define sigmoid function to convert response variable to probabilities

# %%
subset_combined["Time_in_seconds"] = Quarter*15*60 - minutes*60 - seconds 

subset_combined["YardLine"] = Yardline


subset_combined["Down"] = Down

# %%
all_combination_test = subset_combined.drop(columns=["SeriesFirstDown", "GameId", "GameDate", 
                                     "ToGo", "Yards", "Description", "SeasonYear",
                                      "Formation", "OffenseTeam", "DefenseTeam", "Quarter", "Minute", "Second", "Yards_vs_ToGo"
                                     ], axis=1)


all_combination_test.shape
# Out:
# (92, 1420)

# %%
def sigmoid(alpha, x):
    '''
    Define sigmoid function to convert y pred value to probabilities
    '''
    return 1.0 / (1.0 + np.exp(0-alpha*x))


y_pred = mixed_best.predict(all_combination_test)


sigmoid_y_pred = [sigmoid((max(100-Yardline-togo, 0)+50)/100, x - Down/2) for x in y_pred]


all_combination_test["sigmoid_y_pred"] = sigmoid_y_pred


final_res_df = all_combination_test.sort_values(["sigmoid_y_pred"], ascending=False).head()

print(final_res_df)
# Out:
#                     Offense_0 Offense_1 Offense_2 Offense_3 Offense_4  \
# Formation
# NO HUDDLE SHOTGUN 3      77.0      82.0      86.0      67.0      83.0
# SHOTGUN           3      77.0      82.0      86.0      67.0      83.0
# UNDER CENTER      3      77.0      82.0      86.0      67.0      83.0
# NO HUDDLE         3      77.0      82.0      86.0      67.0      83.0
# NO HUDDLE SHOTGUN 2      77.0      82.0      86.0      67.0      83.0
#
#                     Offense_5 Offense_6 Offense_7 Offense_8 Offense_9  ...  \
# Formation                                                              ...
# NO HUDDLE SHOTGUN 3      59.0      81.0      73.0      63.0      26.0  ...
# SHOTGUN           3      59.0      81.0      73.0      63.0      26.0  ...
# UNDER CENTER      3      59.0      81.0      73.0      63.0      26.0  ...
# NO HUDDLE         3      59.0      81.0      73.0      63.0      26.0  ...
# NO HUDDLE SHOTGUN 2      59.0      81.0      73.0      63.0      26.0  ...
#
#                     PassType_[58-H.LANDRY III] RushDirection_CENTER  \
# Formation
# NO HUDDLE SHOTGUN 3                        0.0                  0.0
# SHOTGUN           3                        0.0                  0.0
# UNDER CENTER      3                        0.0                  0.0
# NO HUDDLE         3                        0.0                  0.0
# NO HUDDLE SHOTGUN 2                        0.0                  0.0
#
#                     RushDirection_LEFT END RushDirection_LEFT GUARD  \
# Formation
# NO HUDDLE SHOTGUN 3                    0.0                      0.0
# SHOTGUN           3                    0.0                      0.0
# UNDER CENTER      3                    0.0                      0.0
# NO HUDDLE         3                    0.0                      0.0
# NO HUDDLE SHOTGUN 2                    0.0                      0.0
#
#                     RushDirection_LEFT TACKLE RushDirection_RIGHT END  \
# Formation
# NO HUDDLE SHOTGUN 3                       0.0                     0.0
# SHOTGUN           3                       0.0                     0.0
# UNDER CENTER      3                       0.0                     0.0
# NO HUDDLE         3                       0.0                     0.0
# NO HUDDLE SHOTGUN 2                       0.0                     0.0
#
#                     RushDirection_RIGHT GUARD RushDirection_RIGHT TACKLE  \
# Formation
# NO HUDDLE SHOTGUN 3                       0.0                        0.0
# SHOTGUN           3                       0.0                        0.0
# UNDER CENTER      3                       0.0                        0.0
# NO HUDDLE         3                       0.0                        0.0
# NO HUDDLE SHOTGUN 2                       0.0                        0.0
#
#                     Time_in_seconds sigmoid_y_pred
# Formation
# NO HUDDLE SHOTGUN 3            2995       0.653090
# SHOTGUN           3            2995       0.638823
# UNDER CENTER      3            2995       0.638802
# NO HUDDLE         3            2995       0.632756
# NO HUDDLE SHOTGUN 2            2995       0.620758
#
# [5 rows x 1421 columns]

# %% [markdown]
# ### Translate results into football language with "chance of success" (as sigmoid y pred)

# %%
def python_to_football(res_row):
    
    '''
    Function to translate each record into "Football" languages
    '''
    
    formation = ""
    playType = ""
    passType = ""
    rushDirection = ""
    successRate = ""
    
    list_columns = final_res_df.columns.tolist()
    
    assert len(res_row) == len(list_columns)
    
    for i in range(len(res_row)):
        
        if "Formation_" in list_columns[i] and res_row[i] == 1:
            formation = list_columns[i].split("_")[1]
        
        if "PlayType_PASS" in list_columns[i] and res_row[i] == 1:
            playType = "PASS"
        elif "PlayType_RUSH" in list_columns[i] and res_row[i] == 1:
            playType = "RUSH"
        
        if "PassType_" in list_columns[i] and res_row[i] == 1:
            passType = list_columns[i].split("_")[1]
            
        if "RushDirection_" in list_columns[i] and res_row[i] == 1:
            rushDirection = list_columns[i].split("_")[1]
        
        if "sigmoid_" in list_columns[i]:
            successRate = f"{round(res_row[i]*100, 2)}%"
            
            
        
            
    
    if passType != "":
        return(f"{formation} Formation, {playType} Play, {passType}, with {successRate} chance of Success.")
    elif rushDirection != "":
        return(f"{formation} Formation, {playType} Play, {rushDirection}, with {successRate} chance of Success.")



final_res_df.apply(lambda x: python_to_football(x), axis=1).reset_index(drop=True).to_json()
# Out:
# '{"0":"NO HUDDLE SHOTGUN Formation, PASS Play, DEEP MIDDLE, with 65.31% chance of Success.","1":"SHOTGUN Formation, PASS Play, DEEP MIDDLE, with 63.88% chance of Success.","2":"UNDER CENTER Formation, PASS Play, DEEP MIDDLE, with 63.88% chance of Success.","3":"NO HUDDLE Formation, PASS Play, DEEP MIDDLE, with 63.28% chance of Success.","4":"NO HUDDLE SHOTGUN Formation, PASS Play, DEEP LEFT, with 62.08% chance of Success."}'

# %% [markdown]
# ### Save the trained model into pickle file with dill to avoid potential bugs when deploying on Heroku

# %%
#with open("050122_linear_non_linear_model_trained_dill.pkl", "wb") as f:
    dill.dump(mixed_best, f, recurse=True)
    
print("Finished saving the trained model!")
# Out:
# Finished saving the trained model!

# %% [markdown]
# ### Save only (absolutely) neccessary part of the data for predictions in order to reduce memory usage in heroku

# %%
'''
only keep records with unique offense team, formation, and season year for test data
'''
final_combined_data = final_combined_data.drop_duplicates(subset=["OffenseTeam", "DefenseTeam", "Formation", "SeasonYear"])

# %%
final_combined_data.shape
# Out:
# (5332, 1434)

# %%
'''
Confirm for each season year, there are 32 unique offense and 32 unique defense teams after filtering
'''

assert len(final_combined_data.loc[final_combined_data.SeasonYear==2018, ["DefenseTeam"]].drop_duplicates()) == 32
assert len(final_combined_data.loc[final_combined_data.SeasonYear==2019, ["DefenseTeam"]].drop_duplicates()) == 32
assert len(final_combined_data.loc[final_combined_data.SeasonYear==2020, ["DefenseTeam"]].drop_duplicates()) == 32
assert len(final_combined_data.loc[final_combined_data.SeasonYear==2021, ["DefenseTeam"]].drop_duplicates()) == 32


assert len(final_combined_data.loc[final_combined_data.SeasonYear==2018, ["OffenseTeam"]].drop_duplicates()) == 32
assert len(final_combined_data.loc[final_combined_data.SeasonYear==2019, ["OffenseTeam"]].drop_duplicates()) == 32
assert len(final_combined_data.loc[final_combined_data.SeasonYear==2020, ["OffenseTeam"]].drop_duplicates()) == 32
assert len(final_combined_data.loc[final_combined_data.SeasonYear==2021, ["OffenseTeam"]].drop_duplicates()) == 32

# %%
#with open("060922_filtered_final_combined_data_for_prediction.pkl", 'wb') as f:
    '''
    This is the data that will be used for prediction
    '''
    pickle.dump(final_combined_data, f)
print("Finished saving filtered combined data!")
# Out:
# Finished saving filtered combined data!

# %% [markdown]
# ### Potential Caveat: Mislabeled record in play-by-play data (see details below)

# %%
#print 10 wronlgy classified records
#Looks very suspicious, need to go back to check specific game details

"""
Conclusion on misclassified data: most likely mislabeled:
for example, in the test data [0], index in full data 34760, gameID 2020112601
The penalty on one second down was not labeled, the 3 down were missing labeled as Punt 
(but actually it was a pass play then QB was sacked)
The 4th down were mislabeled as PASS play but in fact it is a scored field goal

Proof: youtube game video: https://www.youtube.com/watch?v=ZpJ61jmIi60 @7:00m
ESPN: play by play: https://www.espn.com/nfl/playbyplay?gameid=401220244


Temporarily give up on fixing mislabeled data (040322 WH)

"""

wrong_classfied_ids = [i for i in range(len(y_test)) if y_test[i]!=y_pred_xgb[i]]

for i in wrong_classfied_ids[:10]:
    
    print(f"Here is 10 wrongly classified record {i+1}\n")
    
    data_translation(X_test, y_test, y_pred_xgb_prob, i)

    print("\n")
# Out:
# Here is 10 wrongly classified record 1
#
# Label is 0, predicted probability is 0.9248878359794617
# {'Quarter': 3, 'Time Left': '13m 23s', 'YardLine': 'DAL 22', 'Offense_team': 'WAS', 'Defense_team': 'DAL', 'number of plays': 2.0, 'yards gain': 14, 'Formation': [{'Formation_NO HUDDLE SHOTGUN': 1.0}, {'Formation_SHOTGUN': 1.0}], 'PlayType': [{'PlayType_PASS': 1.0}, {'PlayType_RUSH': 1.0}], 'PassType': [{'PassType_SHORT LEFT': 1.0}], 'RushDirection': [{'RushDirection_LEFT END': 1.0}]}
#
#
# Here is 10 wrongly classified record 8
#
# Label is 1, predicted probability is 0.15021052956581116
# {'Quarter': 3, 'Time Left': '6m 55s', 'YardLine': 'NO 22', 'Offense_team': 'TB', 'Defense_team': 'NO', 'number of plays': 2.0, 'yards gain': 8, 'Formation': [{'Formation_SHOTGUN': 1.0}, {'Formation_UNDER CENTER': 1.0}], 'PlayType': [{'PlayType_RUSH': 2.0}], 'PassType': [], 'RushDirection': [{'RushDirection_LEFT END': 1.0}, {'RushDirection_RIGHT GUARD': 1.0}]}
#
#
# Here is 10 wrongly classified record 33
#
# Label is 0, predicted probability is 0.9158428907394409
# {'Quarter': 3, 'Time Left': '8m 56s', 'YardLine': 'CAR 45', 'Offense_team': 'CAR', 'Defense_team': 'PHI', 'number of plays': 2.0, 'yards gain': 18, 'Formation': [{'Formation_SHOTGUN': 1.0}, {'Formation_UNDER CENTER': 1.0}], 'PlayType': [{'PlayType_PASS': 1.0}, {'PlayType_RUSH': 1.0}], 'PassType': [{'PassType_SHORT LEFT': 1.0}], 'RushDirection': [{'RushDirection_CENTER': 1.0}]}
#
#
# Here is 10 wrongly classified record 49
#
# Label is 0, predicted probability is 0.9685354828834534
# {'Quarter': 2, 'Time Left': '1m 28s', 'YardLine': 'MIN 36', 'Offense_team': 'MIN', 'Defense_team': 'GB', 'number of plays': 1.0, 'yards gain': 61, 'Formation': [{'Formation_SHOTGUN': 1.0}], 'PlayType': [{'PlayType_PASS': 1.0}], 'PassType': [{'PassType_SHORT MIDDLE': 1.0}], 'RushDirection': []}
#
#
# Here is 10 wrongly classified record 65
#
# Label is 0, predicted probability is 0.962800145149231
# {'Quarter': 3, 'Time Left': '0m 47s', 'YardLine': 'MIA 31', 'Offense_team': 'MIN', 'Defense_team': 'MIA', 'number of plays': 2.0, 'yards gain': 17, 'Formation': [{'Formation_UNDER CENTER': 2.0}], 'PlayType': [{'PlayType_PASS': 1.0}, {'PlayType_RUSH': 1.0}], 'PassType': [{'PassType_SHORT RIGHT': 1.0}], 'RushDirection': [{'RushDirection_RIGHT GUARD': 1.0}]}
#
#
# Here is 10 wrongly classified record 72
#
# Label is 0, predicted probability is 0.965773344039917
# {'Quarter': 4, 'Time Left': '8m 23s', 'YardLine': 'NYJ 24', 'Offense_team': 'LA', 'Defense_team': 'NYJ', 'number of plays': 3.0, 'yards gain': 30, 'Formation': [{'Formation_SHOTGUN': 1.0}, {'Formation_UNDER CENTER': 2.0}], 'PlayType': [{'PlayType_PASS': 1.0}, {'PlayType_RUSH': 2.0}], 'PassType': [{'PassType_SHORT LEFT': 1.0}], 'RushDirection': [{'RushDirection_LEFT TACKLE': 1.0}, {'RushDirection_RIGHT GUARD': 1.0}]}
#
#
# Here is 10 wrongly classified record 87
#
# Label is 0, predicted probability is 0.7855222821235657
# {'Quarter': 3, 'Time Left': '0m 6s', 'YardLine': 'MIN 12', 'Offense_team': 'MIN', 'Defense_team': 'DET', 'number of plays': 2.0, 'yards gain': 15, 'Formation': [{'Formation_SHOTGUN': 2.0}], 'PlayType': [{'PlayType_PASS': 1.0}, {'PlayType_RUSH': 1.0}], 'PassType': [{'PassType_SHORT LEFT': 1.0}], 'RushDirection': [{'RushDirection_CENTER': 1.0}]}
#
#
# Here is 10 wrongly classified record 98
#
# Label is 0, predicted probability is 0.9199220538139343
# {'Quarter': 2, 'Time Left': '11m 25s', 'YardLine': 'HOU 25', 'Offense_team': 'LAC', 'Defense_team': 'HOU', 'number of plays': 2.0, 'yards gain': 10, 'Formation': [{'Formation_SHOTGUN': 2.0}], 'PlayType': [{'PlayType_PASS': 1.0}, {'PlayType_RUSH': 1.0}], 'PassType': [{'PassType_SHORT RIGHT': 1.0}], 'RushDirection': [{'RushDirection_LEFT TACKLE': 1.0}]}
#
#
# Here is 10 wrongly classified record 107
#
# Label is 0, predicted probability is 0.896874189376831
# {'Quarter': 1, 'Time Left': '4m 39s', 'YardLine': 'CIN 33', 'Offense_team': 'CIN', 'Defense_team': 'DET', 'number of plays': 3.0, 'yards gain': 23, 'Formation': [{'Formation_SHOTGUN': 2.0}, {'Formation_UNDER CENTER': 1.0}], 'PlayType': [{'PlayType_PASS': 2.0}, {'PlayType_RUSH': 1.0}], 'PassType': [{'PassType_DEEP RIGHT': 1.0}, {'PassType_SHORT RIGHT': 1.0}], 'RushDirection': [{'RushDirection_RIGHT END': 1.0}]}
#
#
# Here is 10 wrongly classified record 141
#
# Label is 0, predicted probability is 0.9642761945724487
# {'Quarter': 2, 'Time Left': '12m 53s', 'YardLine': 'DEN 16', 'Offense_team': 'DEN', 'Defense_team': 'SF', 'number of plays': 1.0, 'yards gain': 11, 'Formation': [{'Formation_UNDER CENTER': 1.0}], 'PlayType': [{'PlayType_RUSH': 1.0}], 'PassType': [], 'RushDirection': [{'RushDirection_LEFT END': 1.0}]}
